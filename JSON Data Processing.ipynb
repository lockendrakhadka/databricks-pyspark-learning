# %%
# Step 1 — Read the JSON file

df = spark.read.option("multiLine", "true").json(
    "/Volumes/workspace/company_db/emp/employees.json"
)

df.show(truncate=False)

# %%
# Step 2 — Check the schema

df.printSchema()
