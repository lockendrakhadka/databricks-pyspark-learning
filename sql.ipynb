# %%
# %sql

CREATE SCHEMA workspace.company_db;

# %%
# %sql

CREATE TABLE workspace.company_db.employees (
    employee_id INT,
    employee_name STRING,
    department STRING,
    job_title STRING,
    salary DOUBLE,
    age INT,
    joining_date DATE
);

# %%
# %sql

INSERT INTO workspace.company_db.employees
VALUES
(1, 'John Smith', 'IT', 'Data Engineer', 65000.00, 28, '2022-06-15'),
(2, 'Sarah Wilson', 'HR', 'HR Manager', 58000.00, 32, '2021-03-10'),
(3, 'Mike Brown', 'Finance', 'Accountant', 52000.00, 29, '2023-01-20'),
(4, 'Emily Davis', 'IT', 'Software Engineer', 72000.00, 26, '2024-02-05'),
(5, 'David Miller', 'Sales', 'Sales Executive', 48000.00, 31, '2020-11-12'),
(6, 'Lisa Taylor', 'Marketing', 'Marketing Analyst', 55000.00, 27, '2023-07-18'),
(7, 'James Anderson', 'IT', 'Data Analyst', 60000.00, 30, '2022-09-25');

# %%
# %sql

SELECT *
FROM workspace.company_db.employees;
