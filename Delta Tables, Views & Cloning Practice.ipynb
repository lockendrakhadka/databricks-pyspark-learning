# %% [markdown]
# **To check what catalogs we have**

# %%
# %sql

show catalogs

# %% [markdown]
# **To check what schemas we have**

# %%
# %sql
show schemas in workspace

# %% [markdown]
# **To check what tabes we have in a schema**

# %%
# %sql
SHOW TABLES IN workspace.company_db;

# %% [markdown]
# **Creating a delta table using if table is not exist**

# %%
# %sql

CREATE TABLE IF NOT EXISTS workspace.company_db.employee_practice_delta (
    emp_id INT,
    emp_name STRING,
    dept_id INT,
    salary DOUBLE
)
USING DELTA;

# %% [markdown]
# **Now we have created a table and if we try to create the table with same name again without using IF NOT EXISTS it will show an error**

# %% [markdown]
# **Insert the values inside the table**

# %%
# %sql

INSERT INTO workspace.company_db.employee_practice_delta
VALUES
    (101, 'Lokesh', 10, 50000),
    (102, 'Rahul', 20, 60000),
    (103, 'Amit', 10, 55000),
    (104, 'Priya', 30, 70000),
    (105, 'Neha', 20, 65000);

# %%
# %sql

INSERT INTO workspace.company_db.employee_practice_delta
(emp_id, emp_name, dept_id, salary)
VALUES (106, 'Rohan', 30, 72000);

INSERT INTO workspace.company_db.employee_practice_delta
(emp_id, emp_name, dept_id, salary)
VALUES (107, 'Sneha', 10, 68000);

INSERT INTO workspace.company_db.employee_practice_delta
(emp_id, emp_name, dept_id, salary)
VALUES (108, 'Karan', 20, 75000);

INSERT INTO workspace.company_db.employee_practice_delta
(emp_id, emp_name, dept_id, salary)
VALUES (109, 'Anjali', 30, 80000);

# %% [markdown]
# **Check if the data insertion is done**

# %%
# %sql
SELECT *
FROM workspace.company_db.employee_practice_delta;

# %% [markdown]
# **To check the versions**

# %%
# Delta Time Travel

# %%
# %sql

DESCRIBE HISTORY workspace.company_db.employee_practice_delta;

# %% [markdown]
# **Check the specific version of the delta table**

# %%
# %sql

SELECT *
FROM workspace.company_db.employee_practice_delta
VERSION AS OF 3;

# %% [markdown]
# **Creating a temporary view**

# %%
# %sql

-- Create Temporary 

CREATE OR REPLACE TEMP VIEW employee_temp_view AS
SELECT *
FROM workspace.company_db.employee_practice_delta;

# %% [markdown]
# **Checking the temp view**

# %%
# %sql

SELECT *
FROM employee_temp_view;

# %% [markdown]
# **Creating a permanent view**

# %%
# %sql

-- Create Permanent Views

CREATE OR REPLACE VIEW workspace.company_db.employee_permanent_view AS
SELECT *
FROM workspace.company_db.employee_practice_delta;

# %% [markdown]
# **To Check data inside the permanent view**

# %%
# %sql

SELECT *
FROM workspace.company_db.employee_permanent_view;

# %% [markdown]
# **To check both temp & permanent view**

# %%
# %sql

SHOW VIEWS IN workspace.company_db;
